# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
rc = {'figure.figsize':(10,5),
      'axes.facecolor':'white',
      'axes.grid' : True,
      'grid.color': '.8',
      'font.family':'Times New Roman',
      'font.size' : 15}
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.rcParams.update(rc)

# %%
#1
df = pd.read_csv("TSLA.csv", low_memory=False, parse_dates=[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
#2
plt.plot(df.Date, df.Open)

# %%
#3
df.rename(columns={"Adj Close":"AdjClose"}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   AdjClose   1259 non-null   float64
#  6   Volume     1259 non-null   int64
#  7   InAverage  1259 non-null   float64
#  8   InSum      1259 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 88.6 KB

# %%
#4
df.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# AdjClose     False
# Volume       False
# InAverage    False
# InSum        False
# dtype: bool

# %%
#4
df.isna().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# AdjClose     False
# Volume       False
# InAverage    False
# InSum        False
# dtype: bool

# %%
#5
df['InAverage'] = (df.Open+df.Close+df.High+df.Low+df.AdjClose)/5
df['InSum'] = df.Volume * df.InAverage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   AdjClose   1259 non-null   float64
#  6   Volume     1259 non-null   int64
#  7   InAverage  1259 non-null   float64
#  8   InSum      1259 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 88.6 KB

# %%
df.head()
# Out:
#         Date       Open       High        Low      Close   AdjClose  \
# 0 2017-09-18  25.350000  25.974001  25.178667  25.666668  25.666668
# 1 2017-09-19  25.333332  25.492666  24.904667  25.006666  25.006666
# 2 2017-09-20  24.866667  25.216667  24.738001  24.927334  24.927334
# 3 2017-09-21  24.993334  25.122000  24.300667  24.431999  24.431999
# 4 2017-09-22  24.432667  24.660000  23.392000  23.406000  23.406000
#
#       Volume  InAverage         InSum
# 0  107820000  25.567201  2.756656e+09
# 1   96778500  25.148799  2.433863e+09
# 2   73786500  24.935201  1.839881e+09
# 3   69273000  24.656000  1.707995e+09
# 4  122391000  23.859333  2.920168e+09

# %%
#6
plt.plot(df.Date, df.InSum)
